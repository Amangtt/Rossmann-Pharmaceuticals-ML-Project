# %%
import os, sys
import pandas as pd
current_dir = os.getcwd()
parent_dir = os.path.dirname(current_dir)
print(parent_dir)
sys.path.insert(0, parent_dir)
from scripts.data_preprocess import preprocess
from scripts.eda import eda
edaa=eda()
train='C:/Users/hello/Desktop/ML/train.csv'
test='C:/Users/hello/Desktop/ML/test.csv'
stores='C:/Users/hello/Desktop/ML/store.csv'
# Out:
# c:\Users\hello\Desktop\git\Rossmann-Pharmaceuticals-ML-Project

# %%
df_,df_test_,store_=preprocess.load_data(train,test,stores)
# Out:
# 2025-01-04 09:41:27,262- INFO-Loading data....
# c:\Users\hello\Desktop\git\Rossmann-Pharmaceuticals-ML-Project\scripts\data_preprocess.py:10: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df=pd.read_csv(train)

# %%
preprocess.missing_value(df_,df_test_,store_)
# Out:
# 2025-01-04 09:41:34,526- INFO-Checking for missing data....
# Store            0
# DayOfWeek        0
# Date             0
# Sales            0
# Customers        0
# Open             0
# Promo            0
# StateHoliday     0
# SchoolHoliday    0
# dtype: int64
# Id                0
# Store             0
# DayOfWeek         0
# Date              0
# Open             11
# Promo             0
# StateHoliday      0
# SchoolHoliday     0
# dtype: int64
# Store                          0
# StoreType                      0
# Assortment                     0
# CompetitionDistance            3
# CompetitionOpenSinceMonth    354
# CompetitionOpenSinceYear     354
# Promo2                         0
# Promo2SinceWeek              544
# Promo2SinceYear              544
# PromoInterval                544
# dtype: int64

# %%
preprocess.skewed(df_, 'Sales')
# Out:
# 2025-01-04 08:56:23,614- INFO-plotting skewed data....

# %%
df,df_test,store=preprocess.handle_data(df_,df_test_,store_)
# Out:
# 2025-01-04 09:41:44,090- INFO-Handling data....

# %%
edaa.sales_per_day(df)
# Out:
# 2025-01-04 08:56:50,628- INFO-calculating sales per day....
#    DayOfWeek       Sales
# 0          1  1130203012
# 1          2  1020411930
# 2          3   954962863
# 3          4   911177709
# 4          5   980555941
# 5          6   846317735
# 6          7    29551433

# %%
edaa.seasonal(df)
# Out:
# 2025-01-04 08:57:01,012- INFO-calculating which season has the most sales....
# c:\Users\hello\Desktop\git\Rossmann-Pharmaceuticals-ML-Project\scripts\eda.py:68: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=add, x='StateHoliday', y='Sales', palette='coolwarm')
#   StateHoliday    Sales
# 0            a  5890305
# 1            b  1433744
# 2            c   691806

# %%
edaa.corr(df)
# Out:
# 2025-01-04 08:57:08,952- INFO-calculating correlation between sales and customers....
# 0.8947107733016958

# %%
edaa.promo_sales(df)
# Out:
# 2025-01-04 09:30:31,821- INFO-Checking if promotion has an effect on sales....
# 2025-01-04 09:30:43,593- INFO-Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2025-01-04 09:30:45,672- INFO-Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2025-01-04 09:30:47,575- INFO-Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2025-01-04 09:30:47,614- INFO-Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# ...

# %%
edaa.assortment_sales(df,store)
# Out:
# 2025-01-04 09:31:14,673- INFO-Which assortment has the highest sales....
#   Assortment         Sales
# 0          a  4.967538e+06
# 1          b  7.882924e+06
# 2          c  5.568195e+06
# c:\Users\hello\Desktop\git\Rossmann-Pharmaceuticals-ML-Project\scripts\eda.py:128: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=ass, x='Assortment', y='Sales', palette='viridis')

# %%
edaa.comp(df,store)
# Out:
# 2025-01-04 09:34:13,640- INFO-The difference in sales before and after the opening of compition....
# c:\Users\hello\Desktop\git\Rossmann-Pharmaceuticals-ML-Project\scripts\eda.py:142: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   smthg['Date']=pd.to_datetime(smthg['Date'])
# c:\Users\hello\Desktop\git\Rossmann-Pharmaceuticals-ML-Project\scripts\eda.py:143: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   smthg['SalesYear'] = smthg['Date'].dt.year
# ...

# %%
edaa.dis(df,store)
# Out:
# 2025-01-04 09:38:53,864- INFO-Does distance between compition affect sales....
# -0.024714507194546948

# %%
edaa.highest_sales(df)
# Out:
# 2025-01-04 09:42:02,283- INFO-the highest sales recorded in a single day....
#            Date     Sales
# 349  2013-12-16  15623548
# 356  2013-12-23  14350056
# 545  2014-06-30  13308602
# 350  2013-12-17  13053993
# 335  2013-12-02  12972440
# ..          ...       ...
# 26   2013-01-27    142848
# 358  2013-12-25    142585
# 730  2015-01-01    130162
# 365  2014-01-01    118108
# 0    2013-01-01     97235
#
# [942 rows x 2 columns]
